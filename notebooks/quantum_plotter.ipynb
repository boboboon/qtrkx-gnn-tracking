# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sys
import os
# Turn off warnings and errors due to TF libraries
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  
import time
import datetime
import csv
from random import shuffle
import tensorflow as tf
# import internal scripts

sys.path.insert(1, '/Users/lucascurtin/Desktop/QGNN Repos/qtrkx-gnn-tracking/tools')
from tools import *

sys.path.insert(2, '/Users/lucascurtin/Desktop/QGNN Repos/qtrkx-gnn-tracking')
from test import *
import configs
from sklearn import metrics
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix

import yaml
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/lucascurtin/Desktop/QGNN Repos/qtrkx-gnn-tracking/notebooks/quantum_plotter.ipynb Cell 1 in <cell line: 20>()
#      <a href='vscode-notebook-cell:/Users/lucascurtin/Desktop/QGNN%20Repos/qtrkx-gnn-tracking/notebooks/quantum_plotter.ipynb#W0sZmlsZQ%3D%3D?line=16'>17</a> from tools import *
#      <a href='vscode-notebook-cell:/Users/lucascurtin/Desktop/QGNN%20Repos/qtrkx-gnn-tracking/notebooks/quantum_plotter.ipynb#W0sZmlsZQ%3D%3D?line=18'>19</a> sys.path.insert(2, '/Users/lucascurtin/Desktop/QGNN Repos/qtrkx-gnn-tracking')
# ---> <a href='vscode-notebook-cell:/Users/lucascurtin/Desktop/QGNN%20Repos/qtrkx-gnn-tracking/notebooks/quantum_plotter.ipynb#W0sZmlsZQ%3D%3D?line=19'>20</a> from test import *
#      <a href='vscode-notebook-cell:/Users/lucascurtin/Desktop/QGNN%20Repos/qtrkx-gnn-tracking/notebooks/quantum_plotter.ipynb#W0sZmlsZQ%3D%3D?line=20'>21</a> import configs
#      <a href='vscode-notebook-cell:/Users/lucascurtin/Desktop/QGNN%20Repos/qtrkx-gnn-tracking/notebooks/quantum_plotter.ipynb#W0sZmlsZQ%3D%3D?line=21'>22</a> from sklearn import metrics
#
# File ~/Desktop/QGNN Repos/qtrkx-gnn-tracking/test.py:7, in <module>
#       5 import numpy as np
#       6 from sklearn import metrics
# ----> 7 from tools.tools import *
#       8 #from tools import *
#      10 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tools.tools'; 'tools' is not a package

# %%
validation_path=r'/Users/lucascurtin/Desktop/QGNN Repos/qtrkx-gnn-tracking/SSH_LOGS/run 1/log_validation.csv'
validation_data = pd.read_csv(validation_path)
validation_loss=np.array(validation_data['loss'])
validation_accuracy=np.array(validation_data['accuracy'])

# %%
training_path=r'/Users/lucascurtin/Desktop/QGNN Repos/qtrkx-gnn-tracking/SSH_LOGS/run 1/log_training.csv'
training_data = pd.read_csv(training_path)
training_loss=np.array(training_data['loss'])
training_accuracy=np.array(training_data['accuracy'])

# %%
epochs=np.linspace(1,len(validation_loss)-1,len(validation_loss)-1)


#Our model tests on the data before it trains so we have 21 datapoints for 20 epochs, but we remove this value because it makes it hard to see the difference between future points
plt.plot(epochs, validation_loss[1:],label='Validation')
plt.plot(epochs, training_loss[1:],label='Training')
plt.grid()
plt.xlabel("Number of epochs")
plt.ylabel("Loss")
plt.title("Performance of QGNN on 100 subgraphs")
plt.legend(loc='best')
plt.show()

# %%
plt.plot(epochs, validation_accuracy[1:],label='Validation')
plt.plot(epochs, training_accuracy[1:],label='Training')
plt.grid()
plt.xlabel("Number of epochs")

plt.ylabel("Accuracy")
plt.title("Performance of QGNN on 100 subgraphs")
plt.legend(loc='best')
plt.show()
