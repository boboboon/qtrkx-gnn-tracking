# %%
import sys
import os
# Turn off warnings and errors due to TF libraries
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  
import time
import datetime
import csv
from random import shuffle
import tensorflow as tf
# import internal scripts
from tools.tools import *
from test import test
import configs
from sklearn import metrics
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix

import yaml

# %%
config = yaml.safe_load(open('/Users/lucascurtin/Desktop/QGNN Repos/qtrkx-gnn-tracking/logs/test_CGNN/run2/config.yaml'))

# %%
from qnetworks.CGNN import GNN

GNN.config = config

# %%
def load_params(model, log_path):
    n_layers = len(glob.glob('{}*{}*'.format(log_path,'parameters')))
    if n_layers > 0:
        for idx in range(n_layers):
            param_file = log_path + 'log_parameters_%d'%(idx) + '.csv'
            val_file   = log_path + 'log_validation.csv'
            # read the last line of the parameter file
            with open(param_file, 'r') as f:
                reader = csv.reader(f, delimiter=',')  
                params = np.array(list(reader)).astype(float)[-1]
            with open(val_file, 'r') as f:
                reader = csv.reader(f, delimiter=',')  
                val = np.array(list(reader))
            last_epoch = val.shape[0]-2
            # make sure they have the same shape
            params = np.resize(params, model.trainable_variables[idx].shape)
            # Load the parameter to corresponding layer
            model.trainable_variables[idx].assign(params)
        return model, last_epoch
    else:
        raise ValueError('No parameter log found!')

# %%
model = GNN()

# %%
model, epoch_start = load_params(model, config['log_dir'])

# %%
valid_data = get_dataset(config['valid_dir'], config['n_valid'])
n_test=config['n_valid']

# %%
valid_data = get_dataset(config['valid_dir'], 5)
n_test=5

# %%
#config = load_config(parse_args())
tools.config = config

# %%
for n in range(n_test):

        X, Ri, Ro, y = valid_data[n]

        if n == 0:
            preds = model([map2angle(X), Ri, Ro])
            labels = y
        else:	
            out = model([map2angle(X), Ri, Ro])
            preds  = tf.concat([preds, out], axis=0)
            labels = tf.concat([labels, y], axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [41], line 6
#       3 X, Ri, Ro, y = valid_data[n]
#       5 if n == 0:
# ----> 6     preds = model([map2angle(X), Ri, Ro])
#       7     labels = y
#       8 else:
#
# File ~/Library/Python/3.8/lib/python/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/Python/3.8/lib/python/site-packages/keras/engine/training.py:561, in Model.__call__(self, *args, **kwargs)
#     557         super().__call__(inputs, *copied_args, **copied_kwargs)
#     559     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 561 return super().__call__(*args, **kwargs)
#
# File ~/Library/Python/3.8/lib/python/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/Python/3.8/lib/python/site-packages/keras/engine/base_layer.py:1132, in Layer.__call__(self, *args, **kwargs)
#    1127     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1129 with autocast_variable.enable_auto_cast_variables(
#    1130     self._compute_dtype_object
#    1131 ):
# -> 1132     outputs = call_fn(inputs, *args, **kwargs)
#    1134 if self._activity_regularizer:
#    1135     self._handle_activity_regularization(inputs, outputs)
#
# File ~/Library/Python/3.8/lib/python/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/Desktop/QGNN Repos/qtrkx-gnn-tracking/qnetworks/CGNN.py:67, in GNN.call(self, graph_array)
#      65 for i in range(self.n_iters):           # recurrent iteration of the network
#      66     e = self.EdgeNet(H, Ri, Ro)         # execute EdgeNet
# ---> 67     H = self.NodeNet(H, e, Ri, Ro)      # execute NodeNet using the output of EdgeNet
#      68     H = tf.concat([H,X],axis=1) # update H with the output of NodeNet
#      69 e = self.EdgeNet(H, Ri, Ro)             # execute EdgeNet one more time to obtain edge predictions
#
# File ~/Library/Python/3.8/lib/python/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/Python/3.8/lib/python/site-packages/keras/engine/base_layer.py:1132, in Layer.__call__(self, *args, **kwargs)
#    1127     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1129 with autocast_variable.enable_auto_cast_variables(
#    1130     self._compute_dtype_object
#    1131 ):
# -> 1132     outputs = call_fn(inputs, *args, **kwargs)
#    1134 if self._activity_regularizer:
#    1135     self._handle_activity_regularization(inputs, outputs)
#
# File ~/Library/Python/3.8/lib/python/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/Desktop/QGNN Repos/qtrkx-gnn-tracking/qnetworks/CGNN.py:37, in NodeNet.call(self, X, e, Ri, Ro)
#      35 def call(self,X, e, Ri, Ro):
#      36     bo  = tf.matmul(Ro, X, transpose_a=True)
# ---> 37     bi  = tf.matmul(Ri, X, transpose_a=True)
#      38     Rwo = Ro * e[:,0]
#      39     Rwi = Ri * e[:,0]
#
# File ~/Library/Python/3.8/lib/python/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/Python/3.8/lib/python/site-packages/tensorflow/python/util/dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/Library/Python/3.8/lib/python/site-packages/tensorflow/python/ops/math_ops.py:3714, in matmul(a, b, transpose_a, transpose_b, adjoint_a, adjoint_b, a_is_sparse, b_is_sparse, output_type, name)
#    3711   return gen_math_ops.batch_mat_mul_v3(
#    3712       a, b, adj_x=adjoint_a, adj_y=adjoint_b, Tout=output_type, name=name)
#    3713 else:
# -> 3714   return gen_math_ops.mat_mul(
#    3715       a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#
# File ~/Library/Python/3.8/lib/python/site-packages/tensorflow/python/ops/gen_math_ops.py:6014, in mat_mul(a, b, transpose_a, transpose_b, name)
#    6012 if tld.is_eager:
#    6013   try:
# -> 6014     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6015       _ctx, "MatMul", name, a, b, "transpose_a", transpose_a, "transpose_b",
#    6016       transpose_b)
#    6017     return _result
#    6018   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
fpr, tpr, thresholds = metrics.roc_curve(labels,preds,pos_label=1 )
roc_auc=roc_auc_score(labels, preds)

# %%
plt.figure()
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Area= {:.3f}'.format(roc_auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve for CGNN 1')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### Now going to try and develop confusion matrices.

# %%
preds_np=preds.numpy() #This turns our preds into an array rather than a tf tensor
labels_np=labels.numpy()

# %%
preds_5=preds_np
preds_5[preds_5<0.5]=0

preds_5[preds_5>0.5]=1

# %%
cm_result = metrics.confusion_matrix(labels_np,preds_5)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm_result)

print(disp)

disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x15ecab1f0>

# %%
tn=cm_result[0,0]
fp=cm_result[0,1]
tp=cm_result[1,1]
fn=cm_result[1,0]

n_0=tn + fp
n_1=tp+ fn

print('The number of 0 data points are:',n_0)
print('The number of 1 data points are:',n_1)
print('The imbalance in our classes is:', n_1-n_0)
# Out:
# The number of 0 data points are: 1963
# The number of 1 data points are: 2150
# The imbalance in our classes is: 187

# %% [markdown]
# #### Now going to try and develop histograms.

# %%
# So we would like to split our predictions into predictions made on 0 labels and 1 labels

labels_0=np.where(labels.numpy() == 0)[0]

preds_0=[] #The predictions on all our 0 labels

for i in range(len(labels_0)):

    index=labels_0[i] # grab our index
    guess=preds.numpy()[index] # find our prediction at the corresponding index
    preds_0.append(guess[0])

# %%
# So we would like to split our predictions into predictions made on 0 labels and 1 labels

labels_1=np.where(labels.numpy() == 1)[0]

preds_1=[] #The predictions on all our 1 labels

for i in range(len(labels_1)):


    index=labels_1[i] # grab our index
    guess=preds.numpy()[index] # find our prediction at the corresponding index
    preds_1.append(guess[0])

# %%
preds.numpy()
# Out:
# array([[0.62235737],
#        [0.62235147],
#        [0.62328047],
#        ...,
#        [0.50279343],
#        [0.5078188 ],
#        [0.50250155]], dtype=float32)

# %%
bins = np.linspace(0, 1, 100)

plt.hist(preds_0, bins, alpha=0.5, label='0')
plt.hist(preds_1, bins, alpha=0.5, label='1')
plt.legend(loc='best')
plt.title("Model 1's performance on testing data")
plt.show()
